# %% [markdown]
# # Case study on Presentation of data
#
# * Input data="cars_data.csv"
# * The file contains a sales data of 10000 car models and details like 'Make', 'Model',   'Nickname', 'Car Gender', 'Buyer Gender', 'Buyer Age','Buzzword', 'Country', 'City', 'Dealer     Latitude', 'Dealer Longitude','Color', 'New Car', 'Purchase Date', 'Sale Price',             'Discount','Resell Price', '5-yr Depreciation', 'Top Speed', '0-60 Time'.

# %% [markdown]
#  Do the following operations on ‘cars_data’ dataset:
#  # 1. Read the dataset to the python environment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#reading the dataset
data=pd.read_csv(r'C:\Users\DELNA.RAPHEL\Desktop\New folder\cars_data.csv')
#displaying dataset
data.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  \
# 0  User-friendly   Belgium        Antwerpen        51.247239
# 1      analyzing     China            Jinhu        33.025433
# 2       software     China             Gemo        30.916207
# 3     monitoring  Portugal  Queluz de Baixo        38.745168
# 4       Sharable    Latvia         Jaunpils        56.729980
#
#    Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0          4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# ...

# %% [markdown]
# # 2. Check for the null values present in the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv(r'C:\Users\DELNA.RAPHEL\Desktop\New folder\cars_data.csv')
#checking the sum of null values.
print(data.isnull().sum())

print('\n\nThere are no null values present.')
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64
#
#
# There are no null values present.

# %% [markdown]
# # 3. Plot a bar graph of male vs female buyers participated in the sales.

# %%
a=data[data['Buyer Gender']=='Female']
#Number of females
Female_count=a['Buyer Gender'].count()

#Number of males
Male_count=data['Buyer Gender'].count()-Female_count 
x=['Female','Male']

counts=[Female_count,Male_count] #number of females,males

#bar graph
x_ticks=['Female','Male'] #x_axis

plt.bar(x_ticks,y,width = 0.4,color=['brown','green'] )

plt.ylim(0,6000) #y_limit
plt.title('Male vs Female buyers',color='BLUE',size=15)
plt.ylabel('Number of buyers')

#annotations
for i,j in zip(x,counts):
    plt.annotate(str(j),(i,j+100),color='red',size=12)
    
plt.grid()

# %% [markdown]
# # 4. Find the top 5 cars based on their sales price.

# %%
#sorting datasframe in descending order of Sales price & fetching first 5 rows
best_cars_sorted=data.sort_values('Sale Price',ascending=False).head()

#selecting columns-'Make','Model','Nickname','Sale Price'.
a=best_cars_sorted[['Make','Model','Nickname','Sale Price']]

# creating new index for ranking
index=np.arange(1,6)

# assigning new index
a.index=index
print(' The best 5 cars based on their Sale price:-')
a
# Out:
#  The best 5 cars based on their Sale price:-
#          Make      Model   Nickname  Sale Price
# 1  Volkswagen  Jetta III    Rachael    99997.65
# 2        Audi         A6      Thorn    99991.91
# 3       Lexus         LX      Aldin    99983.38
# 4       Mazda       MX-6  Sylvester    99978.17
# 5       Lexus         ES       Brig    99973.44

# %% [markdown]
# # 5. Find the least 5 cars based on their Resell price.

# %%
#sorting datasframe in ascending order of Resales price & fetching first 5 rows 
least_cars_sorted=data.sort_values('Resell Price').head()

#selecting columns-'Make','Model','Nickname','Resell Price'.
a=least_cars_sorted[['Make','Model','Nickname','Resell Price']]

# creating new index
index=np.arange(1,6)
index

# assigning new index
a.index=index
print(' The least 5 cars based on their Resell price:-')
a
# Out:
#  The least 5 cars based on their Resell price:-
#          Make        Model Nickname  Resell Price
# 1   Chevrolet         1500  Corenda       2000.84
# 2         GMC  Savana 1500     Lark       2005.44
# 3      Jaguar           XF   Payton       2014.09
# 4  Mitsubishi       3000GT     Thia       2017.24
# 5    Infiniti          G37    Sonny       2017.83
